# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('starbucks.csv', index_col='Date', parse_dates=True)

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-09-28  85.519997  86.239998  84.989998  86.070000  86.070000   5976200
# 2020-09-29  86.250000  86.250000  84.629997  84.800003  84.800003   4064000
# 2020-09-30  86.629997  87.160004  85.470001  85.919998  85.919998  10134400
# 2020-10-01  87.040001  87.449997  86.199997  86.739998  86.739998   7231300
# 2020-10-02  85.150002  86.349998  85.089996  86.330002  86.330002    844600

# %%
title = 'TITLE'
xlabel = 'X LABEL'
ylabel = 'Y LABEL'

# %%
df['Close'].plot(figsize=(12,6), title=title, xlim=['2019-10-02','2020-10-02'])

# %%
#qw = df['Close']['2019-10-02':'2020-10-02'].plot(figsize=(12,4))
ax = df['Close'].plot(figsize=(12,6), title=title)

ax.autoscale(axis='both',tight=True)
ax.set(xlabel=xlabel,ylabel=ylabel)
# Out:
# [Text(0, 0.5, 'Y LABEL'), Text(0.5, 0, 'X LABEL')]

# %%
ax = df['Close']['2019-10-02':'2020-10-02'].plot(figsize=(12,4), ls='--',c='red')

# %%
https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
df3.plot(x='A', y='B')

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------------

# %%
from matplotlib import dates

# %%
ax = df['Close'].plot(figsize=(12,6), xlim=['2019-10-02','2020-10-02'], ylim=[60,160])

ax.set(xlabel='')

ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=0))
ax.xaxis.set_major_formatter(dates.DateFormatter('%a-%B-%d'))


ax.xaxis.set_minor_locator()
ax.xaxis.set_minor_formatter

# %%
https://matplotlib.org/api/dates_api.html
